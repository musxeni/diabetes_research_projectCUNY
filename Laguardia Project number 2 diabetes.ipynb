# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv'
df = pd.read_csv(url)
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
list((df.columns))
# Out:
# ['encounter_id',
#  'patient_nbr',
#  'race',
#  'gender',
#  'age',
#  'weight',
#  'admission_type_id',
#  'discharge_disposition_id',
#  'admission_source_id',
#  'time_in_hospital',
#  'payer_code',
#  'medical_specialty',
#  'num_lab_procedures',
#  'num_procedures',
#  'num_medications',
#  'number_outpatient',
#  'number_emergency',
#  'number_inpatient',
#  'diag_1',
#  'diag_2',
#  'diag_3',
#  'number_diagnoses',
#  'max_glu_serum',
#  'A1Cresult',
#  'metformin',
#  'repaglinide',
#  'nateglinide',
#  'chlorpropamide',
#  'glimepiride',
#  'acetohexamide',
#  'glipizide',
#  'glyburide',
#  'tolbutamide',
#  'pioglitazone',
#  'rosiglitazone',
#  'acarbose',
#  'miglitol',
#  'troglitazone',
#  'tolazamide',
#  'examide',
#  'citoglipton',
#  'insulin',
#  'glyburide-metformin',
#  'glipizide-metformin',
#  'glimepiride-pioglitazone',
#  'metformin-rosiglitazone',
#  'metformin-pioglitazone',
#  'change',
#  'diabetesMed',
#  'readmitted']

# %%
df['gender'].value_counts()
# Out:
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: gender, dtype: int64

# %%
df['race'].value_counts().plot(kind = 'bar')
plt.title('Count of race')
plt.xlabel('race of pts')
# Out:
# Text(0.5, 0, 'race of pts')

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df.groupby(['race'])['time_in_hospital'].mean().plot(kind='bar')
plt.xlabel('Race')
plt.ylabel('Time spent in days')
plt.title('Time spent in hospital by race')
# Out:
# Text(0.5, 1.0, 'Time spent in hospital by race')

# %%
df['age'] = df['age'].str[1:-1]

# %%
df['age']
# Out:
# 0          0-10
# 1         10-20
# 2         20-30
# 3         30-40
# 4         40-50
#           ...
# 101761    70-80
# 101762    80-90
# 101763    70-80
# 101764    80-90
# 101765    70-80
# Name: age, Length: 101766, dtype: object

# %%
df
# Out:
#         encounter_id  patient_nbr             race  gender    age weight  \
# 0            2278392      8222157        Caucasian  Female   0-10      ?
# 1             149190     55629189        Caucasian  Female  10-20      ?
# 2              64410     86047875  AfricanAmerican  Female  20-30      ?
# 3             500364     82442376        Caucasian    Male  30-40      ?
# 4              16680     42519267        Caucasian    Male  40-50      ?
# ...              ...          ...              ...     ...    ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  70-80      ?
# 101762     443847782     74694222  AfricanAmerican  Female  80-90      ?
# 101763     443854148     41088789        Caucasian    Male  70-80      ?
# 101764     443857166     31693671        Caucasian  Female  80-90      ?
# 101765     443867222    175429310        Caucasian    Male  70-80      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# ...

# %%
df[(df['race']!= 'Other')& (df['race'] != '?')].groupby(['race'])['num_lab_procedures'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='race'>

# %%
df[(df['race']!= 'Other')& (df['race'] != '?')].groupby(['race'])['time_in_hospital'].mean().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Race')
plt.ylabel('Time spent in days')
plt.title('Time spent in hospital by race')
# Out:
# Text(0.5, 1.0, 'Time spent in hospital by race')

# %%
df['race'].value_counts().plot(kind = 'bar')
plt.title('Count of race')
plt.xlabel('race of pts')
# Out:
# Text(0.5, 0, 'race of pts')

# %%
df.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
df[['diag_1',
       'diag_2', 'diag_3',]]
# Out:
#         diag_1  diag_2 diag_3
# 0       250.83       ?      ?
# 1          276  250.01    255
# 2          648     250    V27
# 3            8  250.43    403
# 4          197     157    250
# ...        ...     ...    ...
# 101761  250.13     291    458
# 101762     560     276    787
# 101763      38     590    296
# 101764     996     285    998
# 101765     530     530    787
#
# [101766 rows x 3 columns]

# %%
sns.boxplot(x='time_in_hospital',y='num_lab_procedures',data=df,hue='gender')
# Out:
# <AxesSubplot:xlabel='time_in_hospital', ylabel='num_lab_procedures'>

# %%
sns.jointplot(x='num_lab_procedures',y='num_medications',data=df,kind='hex')

# %%
df[(df['race']!= 'Other')& (df['race'] != '?')].groupby(['race'])['number_emergency'].mean().sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Race')
plt.ylabel('number_emergency_vists')
plt.title('Time spent in hospital by race')
# Out:
# Text(0.5, 1.0, 'Time spent in hospital by race')

# %%
df[(df['race']!= 'Other')& (df['race'] != '?')]
# Out:
#         encounter_id  patient_nbr             race  gender    age weight  \
# 0            2278392      8222157        Caucasian  Female   0-10      ?
# 1             149190     55629189        Caucasian  Female  10-20      ?
# 2              64410     86047875  AfricanAmerican  Female  20-30      ?
# 3             500364     82442376        Caucasian    Male  30-40      ?
# 4              16680     42519267        Caucasian    Male  40-50      ?
# ...              ...          ...              ...     ...    ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  70-80      ?
# 101762     443847782     74694222  AfricanAmerican  Female  80-90      ?
# 101763     443854148     41088789        Caucasian    Male  70-80      ?
# 101764     443857166     31693671        Caucasian  Female  80-90      ?
# 101765     443867222    175429310        Caucasian    Male  70-80      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# ...

# %%
sns.catplot(x="race", y='time_in_hospital', hue="gender",
                col='readmitted', data=df[(df['race']!= 'Other')& (df['race'] != '?')],kind='bar')

# %%
sns.catplot(x='time_in_hospital', hue="gender",
                col='readmitted', data=df[(df['race']!= 'Other')& (df['race'] != '?')],kind='count')
